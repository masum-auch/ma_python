# %% [markdown]
# <a href="https://colab.research.google.com/github/masum-auch/ma_python/blob/main/ml_python/py_generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Generators | Iterators

# %% [markdown]
# # What is Generators?
#
# Python generators are a simple way of creating iterators.

# %%
#iterables
class mera_range:
  def __init__(self, start, end):
    self.start= start
    self.end= end

  def __init__(self):
    return mera_iterators(self)

#iterators
class mera_iterators:
  def __init__(self, iterable_obj):
    self.iterable= iterable_obj

  def __init__(self):
    return self

  def __next__(self):
    if self.iterable.start > self.iterable.end:
      raise StopIteration

    current= self.iterable.start
    self.iterable.start+=1
    return current

# %% [markdown]
# # The Why

# %%
L= [x for x in range(100000)]

# for i in L:
#   print(i**2)

import sys
L_size= sys.getsizeof(L)
print(L_size)

X= range(1000000)

# for i in X:
#   print(i**2)

X_size= sys.getsizeof(X)
print(X_size)
# Out:
# 800984
# 48

# %% [markdown]
# # A Simple Example

# %%
def my_generator():
  yield 1
  yield 2
  yield 3

for value in my_generator():
  print(value)

sys.getsizeof(my_generator)
# Out:
# 1
# 2
# 3
# 160

# %%
def gen_demo():

  yield "frist statement"
  yield "second statement"
  yield "third Statement"


gen= gen_demo()

# for i in gen_demo():
  # print(i)

print(next(gen))
print(next(gen))
print(next(gen))
# print(next(gen))

sys.getsizeof(gen_demo())
# Out:
# frist statement
# second statement
# third Statement
# 176

# %% [markdown]
# ## Python Tutor Demo (yield vs return)

# %%
https://pythontutor.com/visualize.html#mode=display

# %% [markdown]
# # Example 2

# %%
def square(num):
  for i in range(1, num+1):
    yield i**2



squ= square(10)

print(next(squ))
print(next(squ))
print(next(squ))

print(squ)

for i in squ:
  print(i)
# Out:
# 1
# 4
# 9
# <generator object square at 0x7bd83647de00>
# 16
# 25
# 36
# 49
# 64
# 81
# 100

# %%
def count_up_to(n):
  count = 1
  while count <= n:
    yield count
    count += 1

for num in count_up_to(5):
  print(num)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Range Function using Generator

# %%
def mera_range(start, end):

  for i in mera_range():
    yield i


mera= mera_range(15, 20)

# print(next(mera))
print(mera)
# Out:
# <generator object mera_range at 0x7bd836679220>

# %% [markdown]
# ## Generator Expression

# %%
# list comprehension
L2= [i**2 for i in range(1, 101)]
# L2

# %%
gen2= [i**2 for i in range(1, 101)]

# for i in gen2:
  # print(i)

# %% [markdown]
# ## Memory Efficient

# %%
L3= [x for x in range(1000)]
gen3= (x for x in range(1000000))

print('Size of L in memory',sys.getsizeof(L))
print('Size of gen in memory',sys.getsizeof(gen))
# Out:
# Size of L in memory 800984
# Size of gen in memory 176

# %%
def all_even():
    n = 0
    while True:
        yield n
        n += 2

even_num_gen = all_even()
next(even_num_gen)
next(even_num_gen)
# Out:
# 2

# %% [markdown]
# ## Chaining Generators

# %%
def fibonacci_numbers(nums):
    x, y = 0, 1
    for _ in range(nums):
        x, y = y, x+y
        yield x

def square(nums):
    for num in nums:
        yield num**2

print(sum(square(fibonacci_numbers(10))))
# Out:
# 4895
